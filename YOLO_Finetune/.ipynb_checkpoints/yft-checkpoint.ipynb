# %%
# !apt-get install poppler-utils
# !pip install pdf2image
# !pip install roboflow
from pdf2image import convert_from_path

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="OylgkLpLoHKw0iCTi6dN")
project = rf.workspace("shifs-projects").project("blueprint-symbol-detection")
version = project.version(12)
dataset = version.download("yolov8")
# Out:
# ...
#   Obtaining dependency information for roboflow from https://files.pythonhosted.org/packages/f5/a0/43f565befe2e37bc63a8d2964c7ab55f944c9d1b7375d31870c30a7ae581/roboflow-1.1.63-py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for idna==3.7 from https://files.pythonhosted.org/packages/e5/3e/741d8c82801c347547f8a2a06aa57dbb1992be9e948df2ea0eda2c8b79e8/idna-3.7-py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for opencv-python-headless==4.10.0.84 from https://files.pythonhosted.org/packages/26/d0/22f68eb23eea053a31655960f133c0be9726c6a881547e6e9e7e2a946c4f/opencv_python_headless-4.10.0.84-cp37-abi3-win_amd64.whl.metadata
# ...
#   Obtaining dependency information for pillow-heif>=0.18.0 from https://files.pythonhosted.org/packages/9f/0d/ca94079714327781522576e08fa8490afe601dfceae0727dd6b17dc112cf/pillow_heif-0.22.0-cp311-cp311-win_amd64.whl.metadata
# ...
#    ---------------------------------------- 0.0/85.3 kB ? eta -:--:--
# ...

# %%
# !pip install ultralytics
from ultralytics import YOLO
# Out:
# ...
#   Obtaining dependency information for ultralytics from https://files.pythonhosted.org/packages/c7/03/fb590cfffe5cf5f63248a45fa3a78bbc6e0a07d00cf8277ec6c740bc1f58/ultralytics-8.3.130-py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for ultralytics-thop>=2.0.0 from https://files.pythonhosted.org/packages/a6/10/251f036b4c5d77249f9a119cc89dafe8745dc1ad1f1a5f06b6a3988ca454/ultralytics_thop-2.0.14-py3-none-any.whl.metadata
# ...
#    ---------------------------------------- 0.0/1.0 MB ? eta -:--:--
#    - -------------------------------------- 0.0/1.0 MB 991.0 kB/s eta 0:00:01
#    ----- ---------------------------------- 0.1/1.0 MB 1.7 MB/s eta 0:00:01
#    ------------ --------------------------- 0.3/1.0 MB 2.5 MB/s eta 0:00:01
#    ------------------------- -------------- 0.7/1.0 MB 3.8 MB/s eta 0:00:01
#    ---------------------------------------  1.0/1.0 MB 4.9 MB/s eta 0:00:01
#    ---------------------------------------- 1.0/1.0 MB 4.3 MB/s eta 0:00:00
# ...

# %%
import os
dataset_path = "Blueprint-Symbol-Detection-12"
# os.path.exists(dataset_path)
data_yaml = "Blueprint-Symbol-Detection-12/data.yaml"
# os.path.exists(data_yaml)

import yaml 
with open(data_yaml, 'r') as f:
    data = yaml.load(f, Loader=yaml.SafeLoader)
    
os.path.exists("C:/Users/deshu/YOLO_Finetune/Blueprint-Symbol-Detection-12/valid/images")
# Out:
# True

# %%
# !yolo detect train model=yolov8n.pt data=data.yaml epochs=40 imgsz=960 batch=8
# !yolo detect train model=yolov8n.pt data="C:/Users/deshu/YOLO_Finetune/Blueprint-Symbol-Detection-12/data.yaml" epochs=40 imgsz=960 batch=8
# Out:
# Ultralytics 8.3.130  Python-3.11.5 torch-2.2.2 CUDA:0 (NVIDIA GeForce RTX 3050 Laptop GPU, 4096MiB)
# ...

# %%
# !yolo detect predict model=runs/detect/train2/weights/best.pt source="/content/E004.png" save=True
# !yolo detect predict model="C:\Users\deshu\YOLO_Finetune\yolov8n.pt" source="C:\Users\deshu\YOLO_Finetune\content\E004.png" save=True
# Out:
# Ultralytics 8.3.130  Python-3.11.5 torch-2.2.2 CUDA:0 (NVIDIA GeForce RTX 3050 Laptop GPU, 4096MiB)
# YOLOv8n summary (fused): 72 layers, 3,151,904 parameters, 0 gradients, 8.7 GFLOPs
#
# image 1/1 C:\Users\deshu\YOLO_Finetune\content\E004.png: 448x640 (no detections), 224.1ms
# Speed: 6.4ms preprocess, 224.1ms inference, 21.9ms postprocess per image at shape (1, 3, 448, 640)
# Results saved to runs\detect\predict4
#  Learn more at https://docs.ultralytics.com/modes/predict

# %%
# !yolo detect predict model="C:\Users\deshu\YOLO_Finetune\runs\detect\train9\weights\best.pt" source="C:\Users\deshu\YOLO_Finetune\content\E003.png" save=True
# Out:
# Ultralytics 8.3.130  Python-3.11.5 torch-2.2.2 CUDA:0 (NVIDIA GeForce RTX 3050 Laptop GPU, 4096MiB)
# Model summary (fused): 72 layers, 3,006,233 parameters, 0 gradients, 8.1 GFLOPs
#
# image 1/1 C:\Users\deshu\YOLO_Finetune\content\E003.png: 640x960 (no detections), 166.5ms
# Speed: 11.8ms preprocess, 166.5ms inference, 19.9ms postprocess per image at shape (1, 3, 640, 960)
# Results saved to runs\detect\predict2
#  Learn more at https://docs.ultralytics.com/modes/predict

# %%
# from IPython.display import display, Image
# import os

# prediction_dir = "runs/detect/predict"
# image_files = [f for f in os.listdir(prediction_dir) if f.endswith(".png")]

# for img_file in image_files:
#     print(f"Showing: {img_file}")
#     display(Image(filename=os.path.join(prediction_dir, img_file)))

# %%
# !yolo detect predict model=runs/detect/train3/weights/best.pt \
#     source="/content/E003.png" \
#     save=True
# Out:
# Ultralytics 8.3.129 🚀 Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# Model summary (fused): 72 layers, 3,006,233 parameters, 0 gradients, 8.1 GFLOPs
#
# image 1/1 /content/E003.png: 448x640 (no detections), 35.0ms
# Speed: 5.7ms preprocess, 35.0ms inference, 31.7ms postprocess per image at shape (1, 3, 448, 640)
# Results saved to runs/detect/predict4
# 💡 Learn more at https://docs.ultralytics.com/modes/predict
